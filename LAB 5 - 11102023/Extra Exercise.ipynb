# %%
# !pip install --upgrade certifi
# !pip install autocorrect
# !pip install pyspellchecker
# !pip install --upgrade language-check
# !pip install language-tool-python

# using Autocorrect (pip install autocorrect)
from autocorrect import Speller
spell = Speller(lang='en')
spell('caaaar')
spell('mussage')
spell('survice')
spell('hte')

# using Textblob
from textblob import TextBlob
b1 = TextBlob("I havv goood speling!")
print(b1.correct())
b2 = TextBlob("caaaar")
print(b2.correct())

# using pip install pyspellchecker 
# !pip install pyspellchecker 
from spellchecker import SpellChecker
spell = SpellChecker()
# find those words that may be misspelled
misspelled = spell.unknown(['something', 'is', 'hapenning', 'here'])
# Get the one `most likely` answer
for word in misspelled:
  print(spell.correction(word))
# Get a list of `likely` options
print(spell.candidates(word))

#Grammar and Spell Check using Python
# pip install language-check – Does not work in Colab
# https://pypi.org/project/language-check/
import language_check 
tool = language_check.LanguageTool('en-US') 
text = "he are a human"
match = tool.check(text)
print(match)
print(len(match))
language_check.correct(text, match)

# https://pypi.org/project/language-tool-python/
# !pip install language-tool-python
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')
text = "he are a human"
matches = tool.check(text)
print(len(matches))
tool.correct(text)
# Out:
# Requirement already satisfied: certifi in c:\anaconda\lib\site-packages (2023.7.22)
# Requirement already satisfied: autocorrect in c:\anaconda\lib\site-packages (2.6.1)
# Requirement already satisfied: pyspellchecker in c:\anaconda\lib\site-packages (0.7.2)
# Collecting language-check
#   Using cached language-check-1.1.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: language-check
#   Building wheel for language-check (setup.py): started
#   Building wheel for language-check (setup.py): finished with status 'error'
#   Running setup.py clean for language-check
# Failed to build language-check
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [60 lines of output]
#   Traceback (most recent call last):
#     File "C:\anaconda\Lib\urllib\request.py", line 1348, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\anaconda\Lib\http\client.py", line 1286, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\anaconda\Lib\http\client.py", line 1332, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\anaconda\Lib\http\client.py", line 1281, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\anaconda\Lib\http\client.py", line 1041, in _send_output
#       self.send(msg)
#     File "C:\anaconda\Lib\http\client.py", line 979, in send
#       self.connect()
#     File "C:\anaconda\Lib\http\client.py", line 1458, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\ssl.py", line 517, in wrap_socket
#       return self.sslsocket_class._create(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\ssl.py", line 1108, in _create
#       self.do_handshake()
#     File "C:\anaconda\Lib\ssl.py", line 1379, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Faithlin Hoe\AppData\Local\Temp\pip-install-q6abx2ft\language-check_fe762b5c1448433b9e5ec35a5186ac39\setup.py", line 595, in <module>
#       sys.exit(main())
#                ^^^^^^
#     File "C:\Users\Faithlin Hoe\AppData\Local\Temp\pip-install-q6abx2ft\language-check_fe762b5c1448433b9e5ec35a5186ac39\setup.py", line 590, in main
#       run_setup_hooks(config)
#     File "C:\Users\Faithlin Hoe\AppData\Local\Temp\pip-install-q6abx2ft\language-check_fe762b5c1448433b9e5ec35a5186ac39\setup.py", line 561, in run_setup_hooks
#       language_tool_hook(config)
#     File "C:\Users\Faithlin Hoe\AppData\Local\Temp\pip-install-q6abx2ft\language-check_fe762b5c1448433b9e5ec35a5186ac39\setup.py", line 584, in language_tool_hook
#       download_lt()
#     File "C:\Users\Faithlin Hoe\AppData\Local\Temp\pip-install-q6abx2ft\language-check_fe762b5c1448433b9e5ec35a5186ac39\download_lt.py", line 128, in download_lt
#       with closing(urlopen(url)) as u:
#                    ^^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 216, in urlopen
#       return opener.open(url, data, timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 519, in open
#       response = self._open(req, data)
#                  ^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 536, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 1391, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\anaconda\Lib\urllib\request.py", line 1351, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)>
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for language-check
# ERROR: Could not build wheels for language-check, which is required to install pyproject.toml-based projects
# Requirement already satisfied: language-tool-python in c:\anaconda\lib\site-packages (2.7.1)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from language-tool-python) (2.31.0)
# Requirement already satisfied: tqdm in c:\anaconda\lib\site-packages (from language-tool-python) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->language-tool-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->language-tool-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->language-tool-python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->language-tool-python) (2023.7.22)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm->language-tool-python) (0.4.6)
# I have good spelling!
# caesar
# happening
# {'happening', 'penning', 'henning'}
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 37
#      32 print(spell.candidates(word))
#      34 #Grammar and Spell Check using Python
#      35 # pip install language-check – Does not work in Colab
#      36 # https://pypi.org/project/language-check/
# ---> 37 import language_check
#      38 tool = language_check.LanguageTool('en-US')
#      39 text = "he are a human"
#
# ModuleNotFoundError: No module named 'language_check'
