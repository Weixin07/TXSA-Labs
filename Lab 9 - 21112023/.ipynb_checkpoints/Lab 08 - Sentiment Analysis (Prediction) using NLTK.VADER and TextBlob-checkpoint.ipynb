# %% [markdown]
# ### Sentiment Analysis (Prediction) using NLTK.VADER

# %%
import nltk
# nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

reviews = input("Enter the feedback: ")
result = sia.polarity_scores(reviews)

print(result)

if (result['compound'] == 0):
    print ("The sentiment is Neutral")
else:
    if (result['compound'] > -0):
        print ("The sentiment is Positive")
    else:
        print("The sentiment is Negative")
# Out:
# Enter the feedback: This could have been better
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# The sentiment is Positive

# %%
# Perform sentiment prediction for the reviews stored in a CSV file ~~~~~~~~~~~ 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
import pandas as pd 

data = pd.read_csv("D:/APU/TXSA-CT107-3-3/LAB/LAB 9/opinion_dataset.csv") 
print(data.head())
print()

opinions = data['Opinions']
print(opinions.count())
print()

for line in opinions:
    print(line)
    sent = sia.polarity_scores(line)
    print("The compound is ", sent['compound'])
    if (sent['compound'] == 0):
        print ("The sentiment is Neutral")
    else:
        if (sent['compound'] > -0):
            print ("The sentiment is Positive")
        else:
            print("The sentiment is Negative")
    print()
# Out:
#                                             Opinions Sentiment
# 0                                       Personal sms  Positive
# 1  Banners at high density population locations l...  Positive
# 2                     Opportunity to receive bonuses  Positive
# 3                          Street advertising boards  Positive
# 4                                    Black happines   Negative
#
# 100
#
# Personal sms
# The compound is  0.0
# The sentiment is Neutral
#
# Banners at high density population locations like university / condominium
# The compound is  0.3612
# The sentiment is Positive
#
# Opportunity to receive bonuses
# The compound is  0.7506
# The sentiment is Positive
#
# Street advertising boards
# The compound is  0.0
# The sentiment is Neutral
#
# Black happines
# The compound is  0.0
# The sentiment is Neutral
#
# Monthly promotional schemes for specific products
# The compound is  0.0
# The sentiment is Neutral
#
# Pamplets delivered to each apartments nearby.
# The compound is  0.0
# The sentiment is Neutral
#
# Entrance of the shopping malls seem to display less promotions, If they had a few LED Tv's displaying promotions 24/7 even when the store is closed, that would be an eye catching advertisement scenario.
# The compound is  0.0
# The sentiment is Neutral
#
# A small stall in the vicinity of the store advertising products & promotions encouraging people to visit the store.
# The compound is  0.3818
# The sentiment is Positive
#
# Colourful pamphlets
# The compound is  0.0
# The sentiment is Neutral
#
# On Air like FM
# The compound is  0.3612
# The sentiment is Positive
#
# None
# The compound is  0.0
# The sentiment is Neutral
#
# Pamphlets
# The compound is  0.0
# The sentiment is Neutral
#
# No clue.
# The compound is  -0.296
# The sentiment is Negative
#
# Offers must be realistic rather then fake 80-90% drops, customers are smart to judge whether the discount offered is real or just a gimmick by first increasing then applying an offer.
# The compound is  -0.1027
# The sentiment is Negative
#
# Not happy
# The compound is  -0.4585
# The sentiment is Negative
#
# none
# The compound is  0.0
# The sentiment is Neutral
#
# Discount everyday
# The compound is  0.0
# The sentiment is Neutral
#
# Mega sales
# The compound is  0.0
# The sentiment is Neutral
#
# free delivery to doorstep if buy more than RM50
# The compound is  0.5106
# The sentiment is Positive
#
# Negotiable price if customers buy more of a particular product
# The compound is  0.0
# The sentiment is Neutral
#
# Daily special sales
# The compound is  0.4019
# The sentiment is Positive
#
# Through emails. Notifications pops up when promotions are on
# The compound is  0.0
# The sentiment is Neutral
#
# The items which were promoted should have a long term promotion and warranty in order for the promotion to be a success.
# The compound is  0.7579
# The sentiment is Positive
#
# Code promotions
# The compound is  0.0
# The sentiment is Neutral
#
# Discount when buying about 5-10 or above things , hence the offer shoulde be enjoy by every consumer but not limited as member  other consumer also can enjoy the offer so that every one will come to the shop offenly and enjoy the discount that offered by the shop they get happy then  the buisness becomr better and better
# sometimes give them some free gifts also can be acceptable for the future of shop or company
# The compound is  0.9871
# The sentiment is Positive
#
# Based off real overall reviews by others users or customer
# The compound is  0.0
# The sentiment is Neutral
#
# Sms
# The compound is  0.0
# The sentiment is Neutral
#
# Billboards
# The compound is  0.0
# The sentiment is Neutral
#
# SMS regarding the promotion
# The compound is  0.0
# The sentiment is Neutral
#
# SMS
# The compound is  0.0
# The sentiment is Neutral
#
# By calling person to person.
# The compound is  0.0
# The sentiment is Neutral
#
# Promote in university
# The compound is  0.3818
# The sentiment is Positive
#
# Nothing
# The compound is  0.0
# The sentiment is Neutral
#
# Through TV advertisement.
# The compound is  0.0
# The sentiment is Neutral
#
# Email and sms
# The compound is  0.0
# The sentiment is Neutral
#
# Free gift
# The compound is  0.7351
# The sentiment is Positive
#
# Free samples
# The compound is  0.5106
# The sentiment is Positive
#
# Exhibitions/fairs
# The compound is  0.0
# The sentiment is Neutral
#
# Bundling
# The compound is  0.0
# The sentiment is Neutral
#
# Bundling
# The compound is  0.0
# The sentiment is Neutral
#
# Get trial functional about the product
# The compound is  0.0
# The sentiment is Neutral
#
# SMS
# The compound is  0.0
# The sentiment is Neutral
#
# Would suggest to have a public conference to promote the product and give in depth details about it
# The compound is  0.3818
# The sentiment is Positive
#
# Giving free delivery  services
# The compound is  0.6908
# The sentiment is Positive
#
# Give free
# The compound is  0.5106
# The sentiment is Positive
#
# Whatsapp promotion
# The compound is  0.0
# The sentiment is Neutral
#
# Phone notification but not too exaggerating. Probably once or two a week or month
# The compound is  0.1967
# The sentiment is Positive
#
# Attach the promotion information on th products which are in promo
# The compound is  0.0
# The sentiment is Neutral
#
# End of each month
# The compound is  0.0
# The sentiment is Neutral
#
# Email
# The compound is  0.0
# The sentiment is Neutral
#
# Low prices
# The compound is  -0.2732
# The sentiment is Negative
#
# Efficient for the buyer where they can see the promo brochure or ads
# The compound is  0.4215
# The sentiment is Positive
#
# Notifications through the retailer's mobile app
# The compound is  0.0
# The sentiment is Neutral
#
# Accumulate more points in member card
# The compound is  0.0
# The sentiment is Neutral
#
# door to door promotion
# The compound is  0.0
# The sentiment is Neutral
#
# Buy 5 product and get one product with higher discount like RM 588 to RM 59.90
# The compound is  0.3612
# The sentiment is Positive
#
# Internet marketing
# The compound is  0.0
# The sentiment is Neutral
#
# Facebook
# The compound is  0.0
# The sentiment is Neutral
#
# no comment
# The compound is  -0.296
# The sentiment is Negative
#
# Not available
# The compound is  0.0
# The sentiment is Neutral
#
# Can't think of
# The compound is  0.0
# The sentiment is Neutral
#
# by having free gift
# The compound is  0.7351
# The sentiment is Positive
#
# Advertising promotions
# The compound is  0.0
# The sentiment is Neutral
#
# Do demonstration
# The compound is  0.1027
# The sentiment is Positive
#
# No
# The compound is  -0.296
# The sentiment is Negative
#
# Priorities should be given to customers/ Concern more on how customer would really acknowledge and judge the product in the first look. Therefore the promotion should not only be eye catching yet the use or benefits should be exposed obviously! Hope it would help.
# The compound is  0.8016
# The sentiment is Positive
#
# dance in commercial
# The compound is  0.0
# The sentiment is Neutral
#
# Not a suggestion for a promotional method, but this survey is so long and tedious that i got bored halfway and lied about my answers. Please take this feedback into consideration, and do your best to not complain about it since people who complain will not succeed - Jack Ma
# The compound is  0.6796
# The sentiment is Positive
#
# Online shopping
# The compound is  0.0
# The sentiment is Neutral
#
# I can't think of any, but online promotional methods using minimalist designs are still more attractive to me. They give a sense of exclusivity and not too flashy.
# The compound is  0.6474
# The sentiment is Positive
#
# Word of mouth
# The compound is  0.0
# The sentiment is Neutral
#
# Word of mouth
# The compound is  0.0
# The sentiment is Neutral
#
# Facebook
# The compound is  0.0
# The sentiment is Neutral
#
# Use of Social media platforms
# The compound is  0.0
# The sentiment is Neutral
#
# Banner or poster
# The compound is  0.0
# The sentiment is Neutral
#
# Word of mouth
# The compound is  0.0
# The sentiment is Neutral
#
# Win a free trip to a place
# The compound is  0.7964
# The sentiment is Positive
#
# There should be a more interactive promotion amongst the companies and their consumers/customers
# The compound is  0.0
# The sentiment is Neutral
#
# Artistic works and customer attracting special programs
# The compound is  0.7003
# The sentiment is Positive
#
# Provide samples of the products in moving kiosks advertising the quality and feasibility of the product
# The compound is  0.0
# The sentiment is Neutral
#
# Through friends and family
# The compound is  0.4767
# The sentiment is Positive
#
# Promotional method...should not be a one timer....should be more like a continous scheme where both buyer and seller are satisfied..
# The compound is  0.4201
# The sentiment is Positive
#
# Enough is enough
# The compound is  0.0
# The sentiment is Neutral
#
# SMS
# The compound is  0.0
# The sentiment is Neutral
#
# Whatsapp promotion
# The compound is  0.0
# The sentiment is Neutral
#
# Bundle discount
# The compound is  0.0
# The sentiment is Neutral
#
# Free delivery service
# The compound is  0.5106
# The sentiment is Positive
#
#  Promotion in Wechat
# The compound is  0.0
# The sentiment is Neutral
#
# All good
# The compound is  0.4404
# The sentiment is Positive
#
# Please put more lights
# The compound is  0.3182
# The sentiment is Positive
#
# Integrating a number of promotion methods as a whole complete promo, combining them.
# The compound is  0.0772
# The sentiment is Positive
#
# Price discount
# The compound is  0.0
# The sentiment is Neutral
#
# YouTube ads
# The compound is  0.0
# The sentiment is Neutral
#
# Lucky draws
# The compound is  0.4215
# The sentiment is Positive
#
# Can be more attractive price.
# The compound is  0.4927
# The sentiment is Positive
#
# Social media
# The compound is  0.0
# The sentiment is Neutral
#
# Facebook
# The compound is  0.0
# The sentiment is Neutral
#
# Facebook
# The compound is  0.0
# The sentiment is Neutral
#
# Give promotions more often on products that are used more by customers. Promotions should not be limited to a particular season but should come every month or even every week
# The compound is  0.0857
# The sentiment is Positive

# %% [markdown]
# ### Sentiment Analysis (Prediction) using TextBlob

# %%
# Sentiment Prediction using TextBlob
from textblob import TextBlob
reviews = input("Enter the feedback: ")
sent = TextBlob(reviews)
print(sent.sentiment) # Overall sentiment combined with polarity & subjectivity
print(sent.polarity)
print(sent.subjectivity)
# Out:
# Enter the feedback: Happy
# Sentiment(polarity=0.8, subjectivity=1.0)
# 0.8
# 1.0

# %%
# Consider every sentence in the text input ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

from textblob import TextBlob
reviews = input("Enter the feedback: ")
sent = TextBlob(reviews)
for s in sent.sentences:
    print(s)
    print("The polarity is ", s.polarity)
    if (s.polarity == 0):
        print ("The sentiment is Neutral")
    else:
        if (s.polarity > -0):
            print ("The sentiment is Positive")
        else:
            print("The sentiment is Negative")
# Out:
# Enter the feedback: I am happy
# I am happy
# The polarity is  0.8
# The sentiment is Positive

# %%
# Consider it as overall text input ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

from textblob import TextBlob
reviews = input("Enter the feedback: ")
sent = TextBlob(reviews)
print("The polarity is ", sent.polarity)
if (sent.polarity == 0):
    print ("The sentiment is Neutral")
else:
    if (sent.polarity > -0):
        print ("The sentiment is Positive")
    else:
        print("The sentiment is Negative")
# Out:
# Enter the feedback: I am learning Python
# The polarity is  0.0
# The sentiment is Neutral

# %%
# Perform sentiment prediction for the reviews stored in a CSV file ~~~~~~~~~~~ 
from textblob import TextBlob
import pandas as pd 
data = pd.read_csv("D:/APU/TXSA-CT107-3-3/LAB/LAB 9/opinion_dataset.csv") 
data.head()
opinions = data['Opinions']
opinions.count()

for line in opinions:
    print(line)
    sent = TextBlob(line)
    print("The polarity is ", sent.polarity)
    if (sent.polarity == 0):
        print ("The sentiment is Neutral")
    else:
        if (sent.polarity > -0):
            print ("The sentiment is Positive")
        else:
            print("The sentiment is Negative")
    print()
# Out:
# Personal sms
# The polarity is  0.0
# The sentiment is Neutral
#
# Banners at high density population locations like university / condominium
# The polarity is  0.16
# The sentiment is Positive
#
# Opportunity to receive bonuses
# The polarity is  0.0
# The sentiment is Neutral
#
# Street advertising boards
# The polarity is  0.0
# The sentiment is Neutral
#
# Black happines
# The polarity is  -0.16666666666666666
# The sentiment is Negative
#
# Monthly promotional schemes for specific products
# The polarity is  0.0
# The sentiment is Neutral
#
# Pamplets delivered to each apartments nearby.
# The polarity is  0.0
# The sentiment is Neutral
#
# Entrance of the shopping malls seem to display less promotions, If they had a few LED Tv's displaying promotions 24/7 even when the store is closed, that would be an eye catching advertisement scenario.
# The polarity is  0.033333333333333326
# The sentiment is Positive
#
# A small stall in the vicinity of the store advertising products & promotions encouraging people to visit the store.
# The polarity is  -0.25
# The sentiment is Negative
#
# Colourful pamphlets
# The polarity is  0.0
# The sentiment is Neutral
#
# On Air like FM
# The polarity is  0.0
# The sentiment is Neutral
#
# None
# The polarity is  0.0
# The sentiment is Neutral
#
# Pamphlets
# The polarity is  0.0
# The sentiment is Neutral
#
# No clue.
# The polarity is  0.0
# The sentiment is Neutral
#
# Offers must be realistic rather then fake 80-90% drops, customers are smart to judge whether the discount offered is real or just a gimmick by first increasing then applying an offer.
# The polarity is  0.07182539682539683
# The sentiment is Positive
#
# Not happy
# The polarity is  -0.4
# The sentiment is Negative
#
# none
# The polarity is  0.0
# The sentiment is Neutral
#
# Discount everyday
# The polarity is  -0.2
# The sentiment is Negative
#
# Mega sales
# The polarity is  0.0
# The sentiment is Neutral
#
# free delivery to doorstep if buy more than RM50
# The polarity is  0.45
# The sentiment is Positive
#
# Negotiable price if customers buy more of a particular product
# The polarity is  0.3333333333333333
# The sentiment is Positive
#
# Daily special sales
# The polarity is  0.17857142857142858
# The sentiment is Positive
#
# Through emails. Notifications pops up when promotions are on
# The polarity is  0.0
# The sentiment is Neutral
#
# The items which were promoted should have a long term promotion and warranty in order for the promotion to be a success.
# The polarity is  0.125
# The sentiment is Positive
#
# Code promotions
# The polarity is  0.0
# The sentiment is Neutral
#
# Discount when buying about 5-10 or above things , hence the offer shoulde be enjoy by every consumer but not limited as member  other consumer also can enjoy the offer so that every one will come to the shop offenly and enjoy the discount that offered by the shop they get happy then  the buisness becomr better and better
# sometimes give them some free gifts also can be acceptable for the future of shop or company
# The polarity is  0.30097402597402595
# The sentiment is Positive
#
# Based off real overall reviews by others users or customer
# The polarity is  0.0
# The sentiment is Neutral
#
# Sms
# The polarity is  0.0
# The sentiment is Neutral
#
# Billboards
# The polarity is  0.0
# The sentiment is Neutral
#
# SMS regarding the promotion
# The polarity is  0.0
# The sentiment is Neutral
#
# SMS
# The polarity is  0.0
# The sentiment is Neutral
#
# By calling person to person.
# The polarity is  0.0
# The sentiment is Neutral
#
# Promote in university
# The polarity is  0.0
# The sentiment is Neutral
#
# Nothing
# The polarity is  0.0
# The sentiment is Neutral
#
# Through TV advertisement.
# The polarity is  0.0
# The sentiment is Neutral
#
# Email and sms
# The polarity is  0.0
# The sentiment is Neutral
#
# Free gift
# The polarity is  0.4
# The sentiment is Positive
#
# Free samples
# The polarity is  0.4
# The sentiment is Positive
#
# Exhibitions/fairs
# The polarity is  0.0
# The sentiment is Neutral
#
# Bundling
# The polarity is  0.0
# The sentiment is Neutral
#
# Bundling
# The polarity is  0.0
# The sentiment is Neutral
#
# Get trial functional about the product
# The polarity is  0.0
# The sentiment is Neutral
#
# SMS
# The polarity is  0.0
# The sentiment is Neutral
#
# Would suggest to have a public conference to promote the product and give in depth details about it
# The polarity is  0.0
# The sentiment is Neutral
#
# Giving free delivery  services
# The polarity is  0.4
# The sentiment is Positive
#
# Give free
# The polarity is  0.4
# The sentiment is Positive
#
# Whatsapp promotion
# The polarity is  0.0
# The sentiment is Neutral
#
# Phone notification but not too exaggerating. Probably once or two a week or month
# The polarity is  0.0
# The sentiment is Neutral
#
# Attach the promotion information on th products which are in promo
# The polarity is  0.0
# The sentiment is Neutral
#
# End of each month
# The polarity is  0.0
# The sentiment is Neutral
#
# Email
# The polarity is  0.0
# The sentiment is Neutral
#
# Low prices
# The polarity is  0.0
# The sentiment is Neutral
#
# Efficient for the buyer where they can see the promo brochure or ads
# The polarity is  0.0
# The sentiment is Neutral
#
# Notifications through the retailer's mobile app
# The polarity is  0.0
# The sentiment is Neutral
#
# Accumulate more points in member card
# The polarity is  0.5
# The sentiment is Positive
#
# door to door promotion
# The polarity is  0.0
# The sentiment is Neutral
#
# Buy 5 product and get one product with higher discount like RM 588 to RM 59.90
# The polarity is  0.25
# The sentiment is Positive
#
# Internet marketing
# The polarity is  0.0
# The sentiment is Neutral
#
# Facebook
# The polarity is  0.0
# The sentiment is Neutral
#
# no comment
# The polarity is  0.0
# The sentiment is Neutral
#
# Not available
# The polarity is  -0.2
# The sentiment is Negative
#
# Can't think of
# The polarity is  0.0
# The sentiment is Neutral
#
# by having free gift
# The polarity is  0.4
# The sentiment is Positive
#
# Advertising promotions
# The polarity is  0.0
# The sentiment is Neutral
#
# Do demonstration
# The polarity is  0.0
# The sentiment is Neutral
#
# No
# The polarity is  0.0
# The sentiment is Neutral
#
# Priorities should be given to customers/ Concern more on how customer would really acknowledge and judge the product in the first look. Therefore the promotion should not only be eye catching yet the use or benefits should be exposed obviously! Hope it would help.
# The polarity is  0.2583333333333333
# The sentiment is Positive
#
# dance in commercial
# The polarity is  0.0
# The sentiment is Neutral
#
# Not a suggestion for a promotional method, but this survey is so long and tedious that i got bored halfway and lied about my answers. Please take this feedback into consideration, and do your best to not complain about it since people who complain will not succeed - Jack Ma
# The polarity is  -0.012500000000000011
# The sentiment is Negative
#
# Online shopping
# The polarity is  0.0
# The sentiment is Neutral
#
# I can't think of any, but online promotional methods using minimalist designs are still more attractive to me. They give a sense of exclusivity and not too flashy.
# The polarity is  0.26666666666666666
# The sentiment is Positive
#
# Word of mouth
# The polarity is  0.0
# The sentiment is Neutral
#
# Word of mouth
# The polarity is  0.0
# The sentiment is Neutral
#
# Facebook
# The polarity is  0.0
# The sentiment is Neutral
#
# Use of Social media platforms
# The polarity is  0.03333333333333333
# The sentiment is Positive
#
# Banner or poster
# The polarity is  0.0
# The sentiment is Neutral
#
# Word of mouth
# The polarity is  0.0
# The sentiment is Neutral
#
# Win a free trip to a place
# The polarity is  0.6000000000000001
# The sentiment is Positive
#
# There should be a more interactive promotion amongst the companies and their consumers/customers
# The polarity is  0.5
# The sentiment is Positive
#
# Artistic works and customer attracting special programs
# The polarity is  0.34523809523809523
# The sentiment is Positive
#
# Provide samples of the products in moving kiosks advertising the quality and feasibility of the product
# The polarity is  0.0
# The sentiment is Neutral
#
# Through friends and family
# The polarity is  0.0
# The sentiment is Neutral
#
# Promotional method...should not be a one timer....should be more like a continous scheme where both buyer and seller are satisfied..
# The polarity is  0.5
# The sentiment is Positive
#
# Enough is enough
# The polarity is  0.0
# The sentiment is Neutral
#
# SMS
# The polarity is  0.0
# The sentiment is Neutral
#
# Whatsapp promotion
# The polarity is  0.0
# The sentiment is Neutral
#
# Bundle discount
# The polarity is  0.0
# The sentiment is Neutral
#
# Free delivery service
# The polarity is  0.4
# The sentiment is Positive
#
#  Promotion in Wechat
# The polarity is  0.0
# The sentiment is Neutral
#
# All good
# The polarity is  0.7
# The sentiment is Positive
#
# Please put more lights
# The polarity is  0.5
# The sentiment is Positive
#
# Integrating a number of promotion methods as a whole complete promo, combining them.
# The polarity is  0.15000000000000002
# The sentiment is Positive
#
# Price discount
# The polarity is  0.0
# The sentiment is Neutral
#
# YouTube ads
# The polarity is  0.0
# The sentiment is Neutral
#
# Lucky draws
# The polarity is  0.3333333333333333
# The sentiment is Positive
#
# Can be more attractive price.
# The polarity is  0.65
# The sentiment is Positive
#
# Social media
# The polarity is  0.03333333333333333
# The sentiment is Positive
#
# Facebook
# The polarity is  0.0
# The sentiment is Neutral
#
# Facebook
# The polarity is  0.0
# The sentiment is Neutral
#
# Give promotions more often on products that are used more by customers. Promotions should not be limited to a particular season but should come every month or even every week
# The polarity is  0.27380952380952384
# The sentiment is Positive

# %%
# Converting a CSV file into a text file ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import csv
csv_file = input('Enter the name of your input file: ')
txt_file = input('Enter the name of your output file: ')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# Enter the name of your input file: I am learning Python
# Enter the name of your output file: I am learning Python
